# %% [markdown]
# <a href="https://colab.research.google.com/github/sirigadde/AI_ML-Projects/blob/main/yolov8session.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
import os
if not os.path.isdir("yolov8session"):
  os.makedirs("yolov8session")

# %%
# %cd yolov8session
# Out:
# /content/gdrive/MyDrive/yolov8session

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 9117, done.
# remote: Counting objects: 100% (1226/1226), done.
# remote: Compressing objects: 100% (554/554), done.
# remote: Total 9117 (delta 801), reused 1013 (delta 670), pack-reused 7891
# Receiving objects: 100% (9117/9117), 6.13 MiB | 13.89 MiB/s, done.
# Resolving deltas: 100% (6131/6131), done.
# Updating files: 100% (365/365), done.

# %%
# %cd /content/gdrive/MyDrive/ultralytics
# Out:
# /content/gdrive/MyDrive/ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.6/605.6 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/video.mp4'
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (5682/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 4.8ms
# video 1/1 (5683/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 4.8ms
# video 1/1 (5684/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 4.8ms
# video 1/1 (5685/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 5.3ms
# video 1/1 (5686/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 5.1ms
# video 1/1 (5687/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 5.2ms
# video 1/1 (5688/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 5.0ms
# video 1/1 (5689/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 8.2ms
# video 1/1 (5690/10679) /content/gdrive/MyDrive/ultralytics/video.mp4: 288x640 2 cars, 1 truck, 7.2ms
# ...

# %%
# !yolo predict model=yolov8x.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 185MB/s]
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 71.0ms
# Speed: 2.5ms preprocess, 71.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5

# %%
# !yolo predict model=yolov8x.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people3.jpg'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/people3.jpg: 640x544 7 persons, 1 umbrella, 114.4ms
# Speed: 3.9ms preprocess, 114.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6

# %%
# !yolo predict model=yolov8x.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4'
# Out:
# /bin/bash: yolo: command not found

# %%
# !yolo mode = predict task=segment model=yolov8x-seg.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people3.jpg'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71797696 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/people3.jpg: 640x544 7 persons, 81.8ms
# Speed: 4.0ms preprocess, 81.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %%
# !yolo mode=predict task=segment model=yolov8x-seg.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71797696 parameters, 0 gradients
#
# video 1/1 (1/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 73.6ms
# video 1/1 (2/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 56.6ms
# video 1/1 (3/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 42.0ms
# video 1/1 (4/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 37.5ms
# video 1/1 (5/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 38.2ms
# video 1/1 (6/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 37.3ms
# video 1/1 (7/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 37.0ms
# video 1/1 (8/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 640x320 1 person, 37.2ms
# ...

# %%
# !yolo mode = predict task=classify model=yolov8x-cls.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people3.jpg'
# Out:
# ...
# 100% 110M/110M [00:02<00:00, 57.5MB/s]
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-cls summary (fused): 133 layers, 57404200 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/people3.jpg: 224x224 maypole 0.86, feather_boa 0.02, sarong 0.02, stole 0.01, maillot_(tights) 0.01, 14.2ms
# Speed: 26.0ms preprocess, 14.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict

# %%
# !yolo mode = predict task=classify model=yolov8x-cls.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-cls summary (fused): 133 layers, 57404200 parameters, 0 gradients
#
# video 1/1 (1/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 224x224 hoopskirt 0.33, overskirt 0.17, pajama 0.15, gown 0.10, swing 0.03, 14.9ms
# video 1/1 (2/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 224x224 hoopskirt 0.28, pajama 0.22, overskirt 0.15, gown 0.10, neck_brace 0.03, 14.9ms
# video 1/1 (3/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 224x224 pajama 0.31, hoopskirt 0.23, overskirt 0.12, gown 0.09, shower_cap 0.03, 14.0ms
# video 1/1 (4/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 224x224 pajama 0.41, hoopskirt 0.12, maraca 0.09, overskirt 0.09, gown 0.05, 14.0ms
# video 1/1 (5/67) /content/gdrive/MyDrive/yolov8session/ultralytics/hima.mp4: 224x224 pajama 0.64, overskirt 0.05, maraca 0.05, hoopskirt 0.04, Band_Aid 0.03, 14.1ms
# ...

# %%
# !yolo task=classify mode=predict task=classify source='/content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4'
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 16.8MB/s]
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients
#
# video 1/1 (1/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 jigsaw_puzzle 0.12, crossword_puzzle 0.07, quill 0.04, notebook 0.04, pajama 0.03, 3.9ms
# video 1/1 (2/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 jigsaw_puzzle 0.17, crossword_puzzle 0.12, notebook 0.05, quill 0.04, binder 0.03, 4.1ms
# video 1/1 (3/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 crossword_puzzle 0.22, jigsaw_puzzle 0.21, notebook 0.05, laptop 0.03, binder 0.03, 3.6ms
# video 1/1 (4/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 jigsaw_puzzle 0.24, crossword_puzzle 0.15, notebook 0.04, quill 0.03, binder 0.03, 3.4ms
# ...

# %%
# !yolo mode = predict task=classify model=yolov8l-cls.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4'
# Out:
# ...
# 100% 71.7M/71.7M [00:01<00:00, 65.0MB/s]
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-cls summary (fused): 133 layers, 37465576 parameters, 0 gradients
#
# video 1/1 (1/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 web_site 0.20, quill 0.15, comic_book 0.08, desk 0.06, hand-held_computer 0.05, 10.9ms
# video 1/1 (2/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 quill 0.28, web_site 0.16, comic_book 0.05, desk 0.05, hand-held_computer 0.03, 11.0ms
# video 1/1 (3/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 web_site 0.18, quill 0.15, desk 0.07, comic_book 0.05, binder 0.05, 10.9ms
# video 1/1 (4/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 224x224 web_site 0.19, quill 0.10, jigsaw_puzzle 0.09, comic_book 0.06, desk 0.06, 10.9ms
# ...

# %%
# !yolo mode=predict task=pose model=yolov8x-pose-p6.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-pose-p6 summary (fused): 375 layers, 99141280 parameters, 0 gradients
#
# video 1/1 (1/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 1280x768 2 persons, 134.2ms
# video 1/1 (2/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 1280x768 2 persons, 122.9ms
# video 1/1 (3/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 1280x768 2 persons, 123.1ms
# video 1/1 (4/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 1280x768 2 persons, 122.9ms
# video 1/1 (5/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 1280x768 2 persons, 123.3ms
# video 1/1 (6/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 1280x768 2 persons, 124.2ms
# video 1/1 (7/240) /content/gdrive/MyDrive/yolov8session/ultralytics/cuties.mp4: 1280x768 2 persons, 124.2ms
# ...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=custom_data.yaml epochs=50 imgsz=640
